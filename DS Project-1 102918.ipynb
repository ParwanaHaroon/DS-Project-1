# %%
# Project - 1 Data science

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')

# %%
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')

# %%
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %%
df.dtypes
# Out:
# Indicator                   object
# PUBLISH STATES              object
# Year                         int64
# WHO region                  object
# World Bank income group     object
# Country                     object
# Sex                         object
# Display Value                int64
# Numeric                    float64
# Low                        float64
# High                       float64
# Comments                   float64
# dtype: object

# %%
df1.dtypes
# Out:
# STATION         object
# STATION_NAME    object
# DATE             int64
# PRCP             int64
# SNWD             int64
# SNOW             int64
# TMAX             int64
# TMIN             int64
# WDFG             int64
# PGTM             int64
# WSFG             int64
# WT09             int64
# WT07             int64
# WT01             int64
# WT06             int64
# WT05             int64
# WT04             int64
# WT16             int64
# WT08             int64
# WT18             int64
# WT03             int64
# dtype: object

# %%
#Q:2 - Get the row names from the above files

# row names from the first file
df.index.values
# Out:
# array([2245, 2957, 4456, ..., 2426, 3106, 4655])

# %%
# Q2: part 2: 

df1.index.values
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207])

# %%
#Q:3- Change the column name from any of the above file

df = df.rename(columns={"Indicator": "Reflector"})

# %%
df.head()
# Out:
#                            Reflector PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
# Q:4- Chagne the column name from any of hte above file3 and store
# the changes made permanently.

df.rename(columns={"Reflector": "Shower"}, inplace=True)

# %%
df.head()
# Out:
#                               Shower PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
#Q5: Change the names of multiple columns

df.rename(columns={"PUBLISH STATES": "Publication States", 
                  "WHO region": "WHO Region"}, inplace=True)

# %%
df.head()
# Out:
#                               Shower Publication States  Year  \
# 0   Life expectancy at birth (years)          Published  1990
# 1   Life expectancy at birth (years)          Published  2000
# 2  Life expectancy at age 60 (years)          Published  2012
# 3  Life expectancy at age 60 (years)          Published  2000
# 4   Life expectancy at birth (years)          Published  2012
#
#               WHO Region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# ...

# %%
df.sort_values('Year')
# Out:
#                                                Shower Publication States  \
# 0                    Life expectancy at birth (years)          Published
# 1270                 Life expectancy at birth (years)          Published
# 3193                 Life expectancy at birth (years)          Published
# 3194                 Life expectancy at birth (years)          Published
# 3197                Life expectancy at age 60 (years)          Published
# 1264                 Life expectancy at birth (years)          Published
# 3199                Life expectancy at age 60 (years)          Published
# 1262                Life expectancy at age 60 (years)          Published
# 1259                 Life expectancy at birth (years)          Published
# 3203                Life expectancy at age 60 (years)          Published
# 1273                Life expectancy at age 60 (years)          Published
# 3204                 Life expectancy at birth (years)          Published
# ...

# %%
df.sort_values(['Year', 'Country'], ascending=[True,False])
# Out:
#                                                Shower Publication States  \
# 684                  Life expectancy at birth (years)          Published
# 685                 Life expectancy at age 60 (years)          Published
# 1512                 Life expectancy at birth (years)          Published
# 1925                Life expectancy at age 60 (years)          Published
# 1926                Life expectancy at age 60 (years)          Published
# 3103                 Life expectancy at birth (years)          Published
# 290                  Life expectancy at birth (years)          Published
# 681                 Life expectancy at age 60 (years)          Published
# 1078                 Life expectancy at birth (years)          Published
# 1081                Life expectancy at age 60 (years)          Published
# 1922                 Life expectancy at birth (years)          Published
# 3101                Life expectancy at age 60 (years)          Published
# ...

# %%
df.sort_values(by=['Country'])
# Out:
#                                                Shower Publication States  \
# 2245  Healthy life expectancy (HALE) at birth (years)          Published
# 1393                 Life expectancy at birth (years)          Published
# 3689  Healthy life expectancy (HALE) at birth (years)          Published
# 1396                Life expectancy at age 60 (years)          Published
# 1395                Life expectancy at age 60 (years)          Published
# 147                 Life expectancy at age 60 (years)          Published
# 2959                Life expectancy at age 60 (years)          Published
# 2958                 Life expectancy at birth (years)          Published
# 967                 Life expectancy at age 60 (years)          Published
# 966                  Life expectancy at birth (years)          Published
# 965                  Life expectancy at birth (years)          Published
# 1793                Life expectancy at age 60 (years)          Published
# ...

# %%
# list the rows 11, 24, 37

df.iloc[[11,23,37]]
# Out:
#                                  Shower Publication States  Year  \
# 1394   Life expectancy at birth (years)          Published  2012
# 1393   Life expectancy at birth (years)          Published  2000
# 1931  Life expectancy at age 60 (years)          Published  1990
#
#                  WHO Region World Bank income group      Country     Sex  \
# 1394  Eastern Mediterranean              Low-income  Afghanistan  Female
# 1393  Eastern Mediterranean              Low-income  Afghanistan  Female
# 1931                 Europe     Lower-middle-income      Albania  Female
#
#       Display Value  Numeric  Low  High  Comments
# 1394             61     61.0  NaN   NaN       NaN
# 1393             56     56.0  NaN   NaN       NaN
# 1931             18     18.0  NaN   NaN       NaN

# %%
# list the rows excluding 5, 12, 23 and 56

df.drop([5,12,23,56], axis=0)
# Out:
#                                                Shower Publication States  \
# 2245  Healthy life expectancy (HALE) at birth (years)          Published
# 2957                 Life expectancy at birth (years)          Published
# 4456  Healthy life expectancy (HALE) at birth (years)          Published
# 4457  Healthy life expectancy (HALE) at birth (years)          Published
# 148                 Life expectancy at age 60 (years)          Published
# 1794                Life expectancy at age 60 (years)          Published
# 146                  Life expectancy at birth (years)          Published
# 2798  Healthy life expectancy (HALE) at birth (years)          Published
# 1792                 Life expectancy at birth (years)          Published
# 555                 Life expectancy at age 60 (years)          Published
# 554                  Life expectancy at birth (years)          Published
# 1394                 Life expectancy at birth (years)          Published
# ...

# %%
# Second part of the project

# Load dataset from CSV
users = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv' )
sessions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv' )
products = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv' )
transactions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv') 
print('-'*80)
print(users.head())
print('-'*80)
print(products.head())
print('-'*80)
print(sessions.head())
print('-'*80)
print(transactions.head())
# Out:
# --------------------------------------------------------------------------------
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN
# --------------------------------------------------------------------------------
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66
# --------------------------------------------------------------------------------
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4
# ...

# %%
# Data pre-processing
# changing the object to date
users['Registered'] = pd.to_datetime(users.Registered) 
sessions['SessionDate'] = pd.to_datetime(sessions.SessionDate)
transactions['TransactionDate'] = pd.to_datetime(transactions.TransactionDate)

# %%
users.info()
transactions.info()
sessions.info()
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
# UserID        5 non-null int64
# User          5 non-null object
# Gender        5 non-null object
# Registered    5 non-null datetime64[ns]
# Cancelled     2 non-null object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 280.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
# TransactionID      10 non-null int64
# TransactionDate    10 non-null datetime64[ns]
# UserID             9 non-null float64
# ProductID          10 non-null int64
# Quantity           10 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 480.0 bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
# SessionID      10 non-null int64
# SessionDate    10 non-null datetime64[ns]
# UserID         10 non-null int64
# ...

# %%
# join users to transactions
transactions.merge(users, how='left', on='UserID')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender Registered   Cancelled
# 0     NaN        NaT         NaN
# 1  female 2012-10-23  2016-06-07
# 2  female 2012-10-23  2016-06-07
# 3    male 2012-12-21         NaN
# ...

# %%
# transactions have a userid
transactions['UserID'].isin(users['UserID'])
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# 8    False
# 9     True
# Name: UserID, dtype: bool

# %%
# join users to transactions 

transactions.merge(users, how='inner', left_on = 
                   'UserID', right_on = 'UserID')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender Registered   Cancelled
# 0  female 2012-10-23  2016-06-07
# 1  female 2012-10-23  2016-06-07
# 2  female 2012-10-23  2016-06-07
# 3  female 2012-10-23  2016-06-07
# 4    male 2012-12-21         NaN
# 5    male 2010-08-01  2010-08-08
# 6    male 2010-08-01  2010-08-08

# %%
# displaying all matching rows and non matching rows
pd.merge(left=transactions, right=users, how='outer', left_on = 'UserID', right_on = 'UserID')
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaT     4.0        NaN       NaN   Brielle
# 11            NaN             NaT     5.0        NaN       NaN  Benjamin
#
# ...

# %%
# sessions occured on the same day each user reigstered

pd.merge(left=users,right=sessions, how='inner',left_on=['UserID','Registered'], right_on=['UserID','SessionDate'])
# Out:
#    UserID     User  Gender Registered   Cancelled  SessionID SessionDate
# 0       2    Pedro    male 2010-08-01  2010-08-08          2  2010-08-01
# 1       4  Brielle  female 2013-07-17         NaN          9  2013-07-17

# %%
# dataset with every possible 

import numpy as np
df2=pd.DataFrame({'key': np.repeat(1,users.shape[0]), 'UserID':users.UserID}) # Creating new dataframe of users only for the UserID
df2
# Out:
#    key  UserID
# 0    1       1
# 1    1       2
# 2    1       3
# 3    1       4
# 4    1       5

# %%
users_1 = users
users_1['key'] = 0
products_1 = products
products_1['key'] = 0
pd.merge(users_1, products_1, on='key', how="outer")[['UserID', 'ProductID']]
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %%
df3=pd.DataFrame({'key':np.repeat(1,users.shape[0]), 'ProductID':products.ProductID})  # Creating new dataframe of products only for the ProductID
df3
# Out:
#    key  ProductID
# 0    1          1
# 1    1          2
# 2    1          3
# 3    1          4
# 4    1          5

# %%
# display for each user

pd.merge(transactions, transactions, on='UserID')
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# ...

# %%
users.head(2)
# Out:
#    UserID     User Gender Registered   Cancelled  key
# 0       1  Charles   male 2012-12-21         NaN    0
# 1       2    Pedro   male 2010-08-01  2010-08-08    0

# %%
data=pd.merge(users, transactions.groupby('UserID').first().reset_index(), how='left', on='UserID')
data
# Out:
#    UserID      User  Gender Registered   Cancelled  key  TransactionID  \
# 0       1   Charles    male 2012-12-21         NaN    0            4.0
# 1       2     Pedro    male 2010-08-01  2010-08-08    0            5.0
# 2       3  Caroline  female 2012-10-23  2016-06-07    0            2.0
# 3       4   Brielle  female 2013-07-17         NaN    0            NaN
# 4       5  Benjamin    male 2010-11-25         NaN    0            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaT        NaN       NaN
# 4             NaT        NaN       NaN

# %%
# drop columns
data.drop('key', axis=1, inplace=True)
my_columns = list(data.columns) 
my_columns
# Out:
# ['UserID',
#  'User',
#  'Gender',
#  'Registered',
#  'Cancelled',
#  'TransactionID',
#  'TransactionDate',
#  'ProductID',
#  'Quantity']

# %%
# get the lsit of all columns

list(data.dropna(thresh=int(data.shape[0] * .9), axis=1).columns)
# Out:
# ['UserID', 'User', 'Gender', 'Registered']
